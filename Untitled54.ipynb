# %% [markdown]
# <a href="https://colab.research.google.com/github/Nekhaenko/test/blob/main/Untitled54.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/drive/MyDrive/amts.zip -d /content/drive/MyDrive/

# %%
import asyncio
import logging
import sys
import signal
from pathlib import Path
from typing import Any, Dict, List, Optional, Tuple
from datetime import datetime
from pathlib import Path
import yaml
import numpy as np
import pandas as pd

# %%
from pathlib import Path
current_dir = Path.cwd()  # /content
parent_dir = current_dir.parent  # родительская папка
print(parent_dir)  # выводит путь
# Out:
# /

# %%
sys.path.insert(0, str(Path('/content/drive/MyDrive/amts').parent))

# %%
from amts.data.market_data import MarketDataPipeline, OHLCV
from amts.models.embedding_encoder import TemporalPatternEncoder, EncoderConfig, create_encoder
from amts.memory.memory_bank import MemoryBank, MemoryBankManager, PatternAnalyzer
from amts.regime.market_regime_detector import RegimeDetector, MarketRegime
from amts.decision.decision_engine import DecisionEngine, DecisionContext, TradingSignal, SignalType
from amts.risk.risk_manager import RiskManager, Position
from amts.training.adaptive_trainer import AdaptiveTrainer, TradeRecord, PerformanceMetrics
from amts.execution.exchange_connector import ExchangeConnector, PaperTrader, OrderSide, PositionSide
